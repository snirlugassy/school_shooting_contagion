# %%
import re
from  datetime import datetime, timedelta

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tqdm

# %%
X = pd.read_excel('SSDB_Raw_Data.xlsx', 'INCIDENT')
X['Date'] = X['Date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
X = pd.read_excel('SSDB_Raw_Data.xlsx', 'INCIDENT')
# X['year'] = X['Date'].apply(lambda d: int(d[:4]))
X['Date'] = X['Date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))
X = X[X['Date'] >= datetime(year=2010,month=1,day=1)]
X
# Out:
#         Incident_ID                                            Sources  \
# 0     20200727AZCAO  https://www.kgun9.com/news/education/man-dies-...
# 1     20200721SCBRO  https://abcnews4.com/news/crime-news/person-of...
# 2     20200714MIWID  https://www.detroitnews.com/story/news/local/m...
# 3     20200704INLAM  https://www.abc57.com/news/murder-suspect-char...
# 4     20200701ILFRP  https://www.dailyherald.com/news/20200714/pros...
# ...             ...                                                ...
# 2062  20220605INWEG  https://abc7chicago.com/gary-indiana-shooting-...
# 2063  20220607MIPED  https://www.wxyz.com/news/shots-fired-at-persh...
# 2064  20220608ARLIL  https://www.kark.com/crime/lrpd-school-bus-hit...
# 2065  20220609ALWAG  https://www.live5news.com/2022/06/09/potential...
# 2066  20220610ALBYB  https://www.actionnews5.com/2022/06/10/student...
#
#      Number_News Media_Attention  Reliability       Date Quarter  \
# 0              3           Local            4 2020-07-27  Summer
# 1              2           Local            3 2020-07-21  Summer
# 2              1           Local            3 2020-07-14  Summer
# 3              2           Local            4 2020-07-04  Summer
# 4              1           Local            3 2020-07-01  Summer
# ...          ...             ...          ...        ...     ...
# 2062           2           Local            4 2022-06-05  Summer
# 2063           4           Local            4 2022-06-07  Summer
# 2064           5        National            4 2022-06-08  Summer
# 2065         100        National            4 2022-06-09  Summer
# 2066           3           Local            4 2022-06-10  Summer
#
#                                School              City State  ... Accomplice  \
# 0          Canyon del Oro High School        Oro Valley    AZ  ...         No
# 1         Brookdale Elementary School        Orangeburg    SC  ...         No
# 2      Willow Woods Elementary School           Detroit    MI  ...         No
# 3        Lake Hills Elementary School     Michigan City    IN  ...         No
# 4             Frost Elementary School  Prospect Heights    IL  ...        Yes
# ...                               ...               ...   ...  ...        ...
# 2062     West Side Leadership Academy              Gary    IN  ...        NaN
# 2063             Pershing High School           Detroit    MI  ...        NaN
# 2064  Little Rock School District Bus       Little Rock    AR  ...        NaN
# 2065    Walnut Park Elementary School           Gadsden    AL  ...        NaN
# 2066              Byhalia High School           Byhalia    MS  ...        NaN
#
#      Hostages Barricade Officer_Involved Bullied Domestic_Violence  \
# 0          No        No               No      No                No
# 1          No        No               No      No                No
# 2          No        No               No      No                No
# 3          No        No               No      No                No
# 4          No        No               No      No                No
# ...       ...       ...              ...     ...               ...
# 2062       No        No               No      No                No
# 2063       No        No               No      No                No
# 2064       No        No               No      No                No
# 2065      NaN       NaN              NaN     NaN               NaN
# 2066       No        No               No      No                No
#
#      Gang_Related Preplanned Shots_Fired Active_Shooter_FBI
# 0              No         No         NaN                 No
# 1             NaN         No         NaN                 No
# 2              No         No         NaN                 No
# 3              No         No         NaN                 No
# 4             Yes         No         NaN                 No
# ...           ...        ...         ...                ...
# 2062          NaN         No          99                 No
# 2063          NaN         No          99                 No
# 2064          NaN         No          99                 No
# 2065          NaN        NaN         NaN                 No
# 2066          NaN         No           1                 No
#
# [1034 rows x 30 columns]

# %%
min_date, max_date = X['Date'].min(), X['Date'].max()
min_date, max_date
# Out:
# (Timestamp('2010-01-20 00:00:00'), Timestamp('2022-06-10 00:00:00'))

# %%
max_date - min_date
# Out:
# Timedelta('4524 days 00:00:00')

# %% [markdown]
# ## Method A

# %%
DAY = timedelta(days=1)
WEEK = timedelta(weeks=1) 

shooting_date = X['Date'].sort_values()
d = min_date
last_date = max_date - WEEK

S = []
with tqdm.tqdm(total=(last_date - d).days) as pbar:
    while d < last_date:
        d_shooting = shooting_date[shooting_date > d][shooting_date <= d + WEEK]
        S.append((d, d in shooting_date.values, len(d_shooting)))
        d += DAY
        pbar.update(1)
# Out:
# 100%|██████████| 4517/4517 [00:06<00:00, 721.96it/s]

# %%
SDF = pd.DataFrame(S, columns=['date', 'shooting_occured', 'shooting_in_next_week'])
SDF
# Out:
#            date  shooting_occured  shooting_in_next_week
# 0    2010-01-20              True                      0
# 1    2010-01-21             False                      0
# 2    2010-01-22             False                      0
# 3    2010-01-23             False                      0
# 4    2010-01-24             False                      0
# ...         ...               ...                    ...
# 4512 2022-05-29              True                      4
# 4513 2022-05-30              True                      3
# 4514 2022-05-31              True                      3
# 4515 2022-06-01              True                      3
# 4516 2022-06-02             False                      4
#
# [4517 rows x 3 columns]

# %%
s1_mean = SDF[SDF.shooting_occured].shooting_in_next_week.mean()
s2_mean = SDF[~SDF.shooting_occured].shooting_in_next_week.mean()
s1_mean, s2_mean
# Out:
# (3.1918678526048283, 1.2587131367292226)

# %%
print('Average difference in "next week shooting count" between days with/out shootings')
print(s1_mean - s2_mean)
# Out:
# Average difference in "next week shooting count" between days with/out shootings
# 1.9331547158756057

# %% [markdown]
# # Method B

# %%
DAY = timedelta(days=1)
WEEK = timedelta(weeks=1) 

shooting_date = X['Date'].sort_values()
d = min_date + WEEK
last_date = max_date

S = []
with tqdm.tqdm(total=(last_date - d).days) as pbar:
    while d < last_date:
        d_shooting = shooting_date[shooting_date < d][shooting_date >= d - WEEK]
        S.append((d, d in shooting_date.values, len(d_shooting)))
        d += DAY
        pbar.update(1)

SDF = pd.DataFrame(S, columns=['date', 'shooting_occured', 'shooting_in_prev_week'])
SDF
# Out:
# 100%|██████████| 4517/4517 [00:05<00:00, 795.03it/s]
#            date  shooting_occured  shooting_in_prev_week
# 0    2010-01-27             False                      1
# 1    2010-01-28             False                      0
# 2    2010-01-29             False                      0
# 3    2010-01-30             False                      0
# 4    2010-01-31             False                      0
# ...         ...               ...                    ...
# 4512 2022-06-05              True                      4
# 4513 2022-06-06             False                      4
# 4514 2022-06-07              True                      3
# 4515 2022-06-08              True                      3
# 4516 2022-06-09              True                      3
#
# [4517 rows x 3 columns]

# %%
s1_mean = SDF[SDF.shooting_occured].shooting_in_prev_week.mean()
s2_mean = SDF[~SDF.shooting_occured].shooting_in_prev_week.mean()
s1_mean, s2_mean
# Out:
# (3.159493670886076, 1.2632143815401127)

# %%
print('Average difference in "previous week shooting count" between days with/out shootings')
print(s1_mean - s2_mean)
# Out:
# Average difference in "previous week shooting count" between days with/out shootings
# 1.8962792893459632

# %% [markdown]
# ## Counting victims per incident

# %%
victims = pd.read_excel('SSDB_Raw_Data.xlsx', 'VICTIM')

# %%
incident_victim_count = {}
for i, incident_victims in victims.groupby('incidentid'):
    incident_victim_count[i] = len(incident_victims)
incident_victim_count
# Out:
# {'19700105DCHIW': 1,
#  '19700105DCSOW': 1,
#  '19700105DCUNW': 1,
#  '19700206OHJOC': 1,
#  '19700323CADAL': 2,
#  '19700415ARPIP': 6,
#  '19700422DEPIW': 1,
#  '19700508FLCAD': 1,
#  '19700515UTBEO': 2,
#  '19700828TXRIE': 1,
#  '19700831FLALM': 1,
#  '19700914TNHAN': 3,
#  '19700924IDMEM': 1,
#  '19700928IACED': 1,
#  '19701005MIPOD': 4,
#  '19701019TNBOM': 1,
#  '19701020TNWAN': 1,
#  '19701027OHAPM': 1,
#  '19701120ILHAC': 2,
#  '19701212WIXAA': 1,
#  '19710202PAMOP': 1,
#  '19710205PAJOW': 1,
#  '19710210TXOAD': 2,
#  '19710225OHFRC': 1,
#  '19710309AZROT': 1,
#  '19710405PAWIH': 1,
#  '19710527MIBES': 1,
#  '19710602NYEAE': 1,
#  '19710820PAMOM': 1,
#  '19710909TXDUL': 1,
#  '19710924NYMCB': 1,
#  '19710928MNCEM': 1,
#  '19710929VAPEP': 3,
#  '19711028MDCIB': 1,
#  '19711029MDFOB': 1,
#  '19711029MDFRB': 2,
#  '19711103NMCAC': 1,
#  '19711108OKGRT': 1,
#  '19711124MDEDB': 1,
#  '19711206CALOL': 4,
#  '19711213MDCAB': 1,
#  '19720105DCPAW': 1,
#  '19720124OHSTS': 1,
#  '19720126MDGWB': 1,
#  '19720126MDHAB': 1,
#  '19720214ILCAC': 1,
#  '19720215ILKEC': 1,
#  '19720228CAMAL': 1,
#  '19720313TXUNH': 1,
#  '19720412LAEAG': 1,
#  '19720504NVLIR': 1,
#  '19720505INDEI': 1,
#  '19720914TXFRH': 1,
#  '19720915MISAS': 2,
#  '19720919TXCUH': 1,
#  '19720921OHTHA': 1,
#  '19721111CAJEL': 5,
#  '19721127MIPOP': 5,
#  '19721129FLMIM': 1,
#  '19730105NCSOS': 4,
#  '19730118CAJOL': 2,
#  '19730131NCCUB': 1,
#  '19730212ALBOM': 1,
#  '19730226VAARR': 2,
#  '19730405CALOL': 2,
#  '19730501OHRAY': 3,
#  '19730928CAWIL': 3,
#  '19731002ILELA': 1,
#  '19731019MOBES': 1,
#  '19731023MOSUS': 1,
#  '19731023OHBAB': 1,
#  '19731024MNCEM': 1,
#  '19731031MONOS': 1,
#  '19731108ILWOC': 1,
#  '19731109CALOL': 2,
#  '19731206CAFRL': 1,
#  '19731213OHHUC': 1,
#  '19740117ILBAC': 4,
#  '19740122CALOL': 1,
#  '19740207CAJAO': 2,
#  '19740322INBRB': 1,
#  '19740402CTSTB': 2,
#  '19740510TNCHR': 1,
#  '19740519FLHIO': 1,
#  '19740923CAJED': 1,
#  '19740925CASAL': 1,
#  '19741007LADEH': 2,
#  '19741021MDDOB': 1,
#  '19741118SCCAC': 1,
#  '19741121ARBOL': 2,
#  '19741125SCCAC': 1,
#  '19741218CAMAL': 2,
#  '19741230NYOLO': 14,
#  '19750207NYBOM': 1,
#  '19750224NJSTP': 2,
#  '19750312TXJOH': 2,
#  '19750318MOSUS': 1,
#  '19750321OHPAD': 1,
#  '19750321VAFAR': 1,
#  '19750515MOROS': 1,
#  '19750527MIPID': 1,
#  '19750709ILDEC': 1,
#  '19750711MOCES': 2,
#  '19750911OKGRO': 6,
#  '19751001NMHEA': 1,
#  '19751024GAMUA': 1,
#  '19751218CAORS': 1,
#  '19760101AZCAP': 1,
#  '19760123OHCOC': 2,
#  '19760206FLESP': 4,
#  '19760212MIMUD': 5,
#  '19760412TXODF': 2,
#  '19760513MOMAS': 1,
#  '19760514FLPAW': 1,
#  '19760602MDMTC': 1,
#  '19760920NCGUG': 1,
#  '19761110MIBUD': 1,
#  '19761210MOFRS': 2,
#  '19770113ILOLB': 1,
#  '19770209ILFEC': 4,
#  '19770228MOROS': 2,
#  '19770228TXHOA': 1,
#  '19770308ILCOE': 2,
#  '19770321NYPAH': 1,
#  '19770407TXWHW': 1,
#  '19770418TNPIN': 1,
#  '19770517FLSTC': 1,
#  '19770622ILHOC': 2,
#  '19770711COSOC': 1,
#  '19771129MOHAS': 1,
#  '19771129MOVAS': 1,
#  '19771209CAPES': 1,
#  '19771212FLWEW': 1,
#  '19771215MABLC': 2,
#  '19780111KYCHH': 1,
#  '19780209WVHAS': 1,
#  '19780222MIEVL': 2,
#  '19780309CAMOS': 1,
#  '19780329TNGAN': 1,
#  '19780414MIFOD': 1,
#  '19780426TXPAD': 1,
#  '19780428ILRIN': 4,
#  '19780518TXMUA': 1,
#  '19780519PADOP': 8,
#  '19780607DEDOD': 1,
#  '19780610MAWEW': 1,
#  '19781017ALLAL': 1,
#  '19781017MOUNU': 3,
#  '19781129NYPAN': 1,
#  '19781214CTWIN': 1,
#  '19790129CAGRS': 11,
#  '19790226CABAB': 3,
#  '19790314FLMCM': 1,
#  '19790328CALOL': 1,
#  '19790416WIWIM': 1,
#  '19790425PAMAH': 1,
#  '19790426TXAZA': 1,
#  '19790614OHNEN': 1,
#  '19790926LACAN': 2,
#  '19790928MACHC': 1,
#  '19791023MOOFS': 2,
#  '19791105INWAI': 1,
#  '19791130TXUNL': 1,
#  '19791203MDEAB': 3,
#  '19791221MOBLS': 1,
#  '19800107ARSTS': 1,
#  '19800129VALAW': 1,
#  '19800201DCLAW': 1,
#  '19800207TXVAL': 1,
#  '19800211INARI': 1,
#  '19800215MSHUM': 1,
#  '19800320TXJLD': 1,
#  '19800331MDFRB': 1,
#  '19800417VACAC': 2,
#  '19800530NYCLB': 1,
#  '19800902CAWHL': 10,
#  '19800908FLFOJ': 1,
#  '19800910DCSPW': 1,
#  '19800911ALJOM': 1,
#  '19800926CTBRB': 2,
#  '19801013ALCET': 1,
#  '19801031ALHUH': 1,
#  '19801117TXEAF': 1,
#  '19801212ALPAB': 1,
#  '19851018MIMUD': 7,
#  '19851022OHSOG': 1,
#  '19851126WASPS': 2,
#  '19851127ALCHB': 1,
#  '19851203NHCOC': 1,
#  '19851209PAARP': 1,
#  '19851210CTPOP': 3,
#  '19860109NCNOD': 1,
#  '19860117CAVAL': 1,
#  '19860129MDLAB': 1,
#  '19860224LABOS': 1,
#  '19860306ILTHD': 1,
#  '19860423FLCHM': 1,
#  '19860429MOSES': 1,
#  '19860509NCPIF': 3,
#  '19860515GACAA': 1,
#  '19860516WYCOC': 74,
#  '19860517TNMAN': 1,
#  '19860912CAFAL': 1,
#  '19860918CABEB': 1,
#  '19861003CAMOM': 2,
#  '19861008TXSOD': 1,
#  '19861204MTFEL': 4,
#  '19870114CALOL': 1,
#  '19870123MIRED': 1,
#  '19870210ARDAD': 1,
#  '19870213AZORM': 4,
#  '19870224NYMON': 1,
#  '19870302MODED': 1,
#  '19870306TXRIE': 1,
#  '19870330CAPAS': 1,
#  '19870416MIMUD': 3,
#  '19870430ORGRP': 1,
#  '19870503INPII': 1,
#  '19870506ARMAJ': 1,
#  '19870506FLLET': 1,
#  '19870513ILOAO': 1,
#  '19870928ILILL': 1,
#  '19871014ILDUC': 1,
#  '19871030NCSOK': 2,
#  '19871031SCANA': 8,
#  '19871104MISOD': 1,
#  '19871114FLCLC': 1,
#  '19871130TXPES': 1,
#  '19871202FLENJ': 1,
#  '19871204NYEAN': 1,
#  '19871215NYGRB': 1,
#  '19871216TXMAK': 1,
#  '19880105PASPS': 1,
#  '19880106FLGAT': 1,
#  '19880108PACRM': 1,
#  '19880120LASIR': 1,
#  '19880129TXREA': 1,
#  '19880202ALWET': 1,
#  '19880211FLPIL': 3,
#  '19880226RIBRB': 1,
#  '19880304MILED': 1,
#  '19880323CACAS': 1,
#  '19880324TXTRA': 1,
#  '19880505ILMAC': 1,
#  '19880516FLFOF': 1,
#  '19880520ILHUW': 7,
#  '19880531NYPUB': 1,
#  '19880602MSWIJ': 2,
#  '19880617MIJOD': 1,
#  '19880630HIAIO': 1,
#  '19880710WISIM': 1,
#  '19880711MSLAJ': 1,
#  '19880831MICED': 1,
#  '19880831SCWEA': 1,
#  '19880902GAGLA': 2,
#  '19880902NCGAC': 4,
#  '19880903TXLID': 2,
#  '19880922ILMOC': 6,
#  '19880926SCOAG': 11,
#  '19881003FLMAM': 1,
#  '19881004FLJEJ': 5,
#  '19881004LAISB': 1,
#  '19881005MDEDB': 1,
#  '19881006ALMOM': 1,
#  '19881007MDSOB': 1,
#  '19881007TXDIP': 1,
#  '19881101FLPAJ': 1,
#  '19881107UTGLS': 1,
#  '19881122TXABA': 1,
#  '19881216VAATV': 2,
#  '19890105ARHEL': 1,
#  '19890117CACLS': 35,
#  '19890126DCWOW': 4,
#  '19890209IDRIR': 3,
#  '19890210UTTHK': 1,
#  '19890303INWIG': 1,
#  '19890426TXAMD': 1,
#  '19890901VASAV': 2,
#  '19890911AZDYE': 1,
#  '19890918KYJAM': 1,
#  '19891005CALOA': 1,
#  '19891031TXOLD': 1,
#  '19891113NYALN': 1,
#  '20081029CAELG': 1,
#  '20081031MESTS': 1,
#  '20081103CABEB': 1,
#  '20081103CAELO': 1,
#  '20081112FLDIF': 1,
#  '20081115COTHL': 1,
#  '20081115UTDES': 1,
#  '20081118CACEC': 1,
#  '20081118CACOO': 1,
#  '20081125TXNOH': 1,
#  '20081130CAOAG': 1,
#  '20081202CAKIK': 2,
#  '20081205MNSHF': 1,
#  '20081212NCGUA': 1,
#  '20081212NYWIM': 1,
#  '20081221SCSUS': 1,
#  '20081222FLLAL': 1,
#  '20081227PAWIP': 2,
#  '20081231GASHS': 1,
#  '20081231OKKEN': 1,
#  '20090108DEWIN': 2,
#  '20090109ILDUC': 5,
#  ...}

# %%
X['num_victims'] = X['Incident_ID'].apply(lambda _id: incident_victim_count.get(_id, 0))
X[['Incident_ID', 'num_victims']]
# Out:
#         Incident_ID  num_victims
# 0     20200727AZCAO            0
# 1     20200721SCBRO            1
# 2     20200714MIWID            1
# 3     20200704INLAM            1
# 4     20200701ILFRP            1
# ...             ...          ...
# 2062  20220605INWEG            2
# 2063  20220607MIPED            0
# 2064  20220608ARLIL            0
# 2065  20220609ALWAG            1
# 2066  20220610ALBYB            0
#
# [1034 rows x 2 columns]

# %%
"Avg. number of victims:", X.num_victims.mean()
# Out:
# ('Avg. number of victims:', 1.3027079303675049)

# %% [markdown]
# ## Handling missing values

# %%
X['num_news'] = X['Number_News'].replace({
    '1': '1-5', '2': '1-5', '3': '1-5', '4': '1-5', '5': '1-5',
    '6': '5-10', '10': '5-10', 
    '11': '11-100', '20': '11-100', '50': '11-100', '99': '11-100', '100': '11-100',
    '999': '100+', '500': '100+'
})
X['num_news'].unique()
# Out:
# array(['1-5', nan, '11-100', '5-10', '100+'], dtype=object)

# %%
X[X['num_news'].isna()]
# Out:
#         Incident_ID                                            Sources  \
# 9     20200603IAGAD  https://www.ourquadcities.com/news/local-news/...
# 10    20200527OHLUC  https://www.cleveland.com/metro/2020/05/man-sh...
# 11    20200525ALORM  https://www.fox10tv.com/news/mpd-makes-arrest-...
# 12    20200522OHMIC  https://fox8.com/news/man-killed-in-shooting-n...
# 13    20200519VAWEM  https://patch.com/virginia/manassas/suspect-ma...
# ...             ...                                                ...
# 1582  20200917OHELA  https://www.news5cleveland.com/news/local-news...
# 1602  20130129ALDAM  https://www.al.com/montgomery/2013/02/jimmy_le...
# 1629  20160928TNSYP  https://www.scadvocate.com/2016/10/11/armed-st...
# 1881  20211201TXSAP  https://www.khou.com/article/news/crime/armed-...
# 1927  20220114MDGAG  https://www.fox5dc.com/news/man-found-with-gun...
#
#      Number_News Media_Attention  Reliability       Date Quarter  \
# 9            NaN             NaN            4 2020-06-03  Summer
# 10           NaN             NaN            3 2020-05-27  Spring
# 11           NaN             NaN            3 2020-05-25  Spring
# 12           NaN             NaN            2 2020-05-22  Spring
# 13           NaN             NaN            3 2020-05-19  Spring
# ...          ...             ...          ...        ...     ...
# 1582         NaN           Local            4 2020-09-17    Fall
# 1602         NaN   International            5 2013-01-29  Winter
# 1629         NaN        National            5 2016-09-28    Fall
# 1881         NaN           Local            4 2021-12-01  Winter
# 1927         NaN           Local            4 2022-01-14  Winter
#
#                               School           City State  ... Barricade  \
# 9         Garfield Elementary School      Davenport    IA  ...        No
# 10    Luis Munoz Marin Middle School      Cleveland    OH  ...        No
# 11        O Rourke Elementary School         Mobile    AL  ...        No
# 12           Miles Elementary School      Cleveland    OH  ...        No
# 13       West Gate Elementary School       Manassas    VA  ...        No
# ...                              ...            ...   ...  ...       ...
# 1582               Ellet High School          Akron    OH  ...        No
# 1602          Dale County School Bus   Midland City    AL  ...        No
# 1629          Sycamore Middle School  Pleasant View    TN  ...        No
# 1881         Sam Rayburn High School       Pasadena    TX  ...        No
# 1927        Gaithersburg High School   Gaithersburg    MD  ...        No
#
#      Officer_Involved Bullied Domestic_Violence Gang_Related Preplanned  \
# 9                  No      No                No          NaN         No
# 10                 No      No                No           No         No
# 11                 No      No                No           No         No
# 12                 No      No                No          NaN         No
# 13                 No      No                No           No         No
# ...               ...     ...               ...          ...        ...
# 1582               No      No                No          NaN         No
# 1602               No      No                No           No        Yes
# 1629               No     NaN                No           No        Yes
# 1881               No      No                No           No         No
# 1927               No      No                No           No        NaN
#
#      Shots_Fired Active_Shooter_FBI num_victims num_news
# 9            >10                 No           1      NaN
# 10           NaN                 No           1      NaN
# 11           NaN                 No           3      NaN
# 12           NaN                 No           1      NaN
# 13           <10                 No           1      NaN
# ...          ...                ...         ...      ...
# 1582         NaN                 No           2      NaN
# 1602           5                 No           1      NaN
# 1629           0                 No           0      NaN
# 1881           1                 No           1      NaN
# 1927           0                 No           0      NaN
#
# [367 rows x 32 columns]

# %%
X['Situation'].value_counts()
# Out:
# Escalation of Dispute                     321
# Drive-by Shooting                          96
# Accidental                                 92
# Illegal Activity                           76
# Suicide/Attempted                          56
# Indiscriminate Shooting                    47
# Unknown                                    46
# Domestic w/ Targeted Victim                45
# Intentional Property Damage                43
# Hostage/Standoff                           12
# Psychosis                                  10
# Bullying                                    9
# Officer-Involved Shooting                   7
# Self-defense                                6
# Anger Over Grade/Suspension/Discipline      5
# Murder/Suicide                              3
# Name: Situation, dtype: int64

# %%
X['num_sources'] = X['Sources'].str.split(' ').apply(lambda x:len(x))
X[['num_sources', 'num_news']]
# Out:
#       num_sources num_news
# 0               2      1-5
# 1               3      1-5
# 2               1      1-5
# 3               2      1-5
# 4               1      1-5
# ...           ...      ...
# 2062            2      1-5
# 2063            3      1-5
# 2064            2      1-5
# 2065            5   11-100
# 2066            3      1-5
#
# [1034 rows x 2 columns]

# %%
X['num_news'].value_counts()
# Out:
# 1-5       449
# 5-10      126
# 11-100     83
# 100+        9
# Name: num_news, dtype: int64

# %%
X['num_sources'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
def apply_num_news_range(i):
    # '1-5', '11-100', '5-10', '100+'
    if i < 5:
        return '1-5'
    
    if i >= 5 and i <= 10:
        return '5-10'

    if i > 10 and i <= 100:
        return '11-100'

    if i > 100:
        return '100+'

for i, row in X[X['Number_News'].isna()].iterrows():
    X.at[i, 'num_news'] = apply_num_news_range(row['num_sources'])

X['num_news'].unique()
# Out:
# array(['1-5', '5-10', '11-100', '100+'], dtype=object)

# %%
num_news = X['num_news'].value_counts()
plt.figure(figsize=(5,4))
plt.title('Number of news about school shooting events')
plt.barh(num_news.index, num_news.values, align='center', color='c')
plt.xlabel('# Shooting')
plt.ylabel('# News')
# plt.xticks(range(0,500, 50))
plt.show()

# %%
X[['num_news', 'Media_Attention']].value_counts()
# Out:
# num_news  Media_Attention
# 1-5       Local              419
# 5-10      Local               58
#           Regional            57
# 11-100    National            56
# 1-5       Regional            31
# 11-100    Regional            13
# 1-5       National            12
# 5-10      National            12
# 11-100    International       11
# 100+      International        8
# 11-100    Local                3
# 5-10      International        3
# 1-5       International        1
# 100+      National             1
# dtype: int64

# %%
X[['Media_Attention', 'num_victims']].groupby('Media_Attention').mean()
# Out:
#                  num_victims
# Media_Attention
# International       5.347826
# Local               0.875000
# National            2.592593
# Regional            1.267327

# %% [markdown]
# ## Estimating ATE using covariate adjustment

# %%
x = pd.DataFrame(X['Incident_ID'])

x['high_coverage'] = (X['num_news'] != '1-5') * 1

x['num_victims'] = X['num_victims']

x['active_shooter_by_fbi'] = (X['Active_Shooter_FBI'] == 'Yes') * 1
x['gang_related'] = (X['Gang_Related'] == 'Yes') * 1
x['preplanned'] = (X['Preplanned'] == 'Yes') * 1
x['bullied'] = (X['Bullied'] == 'Yes') * 1
x['domestic_violence'] = (X['Domestic_Violence'] == 'Yes') * 1
x['incidents_with_accomplice'] = (X['Accomplice'] == 'Yes') * 1

x['high_school'] = (X['School_Level'] == 'High') * 1
x['middle_school'] = (X['School_Level'] == 'Middle') * 1
x['elementry_school'] = (X['School_Level'] == 'Elementary') * 1

x['in_school'] = (X['Location_Type'].isin(["Inside School Building", "Both Inside/Outside"])) * 1
x['out_school'] = (X['Location_Type'].isin(["Outside on School Property", "Off School Property", "Both Inside/Outside"])) * 1
x['school_bus'] = (X['Location_Type'] == "School Bus") * 1
x['during_school'] = (X['During_School'] == "Yes") * 1
x['is_summer_time'] = (X['Date'].apply(lambda d: d.month in [6,7,8])) * 1
x['targeted'] = (X['Targets'].isin(["Victims Targeted", "Both"])) * 1
x['random_shooting'] = (X['Targets'].isin(["Random Shooting", "Both"])) * 1

for s in X['Situation'].dropna().unique().tolist():
    x['situation_' + re.sub('\W', '_', s).lower()] = (X['Situation'] == s) * 1

x.set_index('Incident_ID', drop=True, inplace=True)

# x.reset_index(drop=True, inplace=True)

x
# Out:
#                high_coverage  num_victims  active_shooter_by_fbi  \
# Incident_ID
# 20200727AZCAO              0            0                      0
# 20200721SCBRO              0            1                      0
# 20200714MIWID              0            1                      0
# 20200704INLAM              0            1                      0
# 20200701ILFRP              0            1                      0
# ...                      ...          ...                    ...
# 20220605INWEG              0            2                      0
# 20220607MIPED              0            0                      0
# 20220608ARLIL              0            0                      0
# 20220609ALWAG              1            1                      0
# 20220610ALBYB              0            0                      0
#
#                gang_related  preplanned  bullied  domestic_violence  \
# Incident_ID
# 20200727AZCAO             0           0        0                  0
# 20200721SCBRO             0           0        0                  0
# 20200714MIWID             0           0        0                  0
# 20200704INLAM             0           0        0                  0
# 20200701ILFRP             1           0        0                  0
# ...                     ...         ...      ...                ...
# 20220605INWEG             0           0        0                  0
# 20220607MIPED             0           0        0                  0
# 20220608ARLIL             0           0        0                  0
# 20220609ALWAG             0           0        0                  0
# 20220610ALBYB             0           0        0                  0
#
#                incidents_with_accomplice  high_school  middle_school  ...  \
# Incident_ID                                                           ...
# 20200727AZCAO                          0            1              0  ...
# 20200721SCBRO                          0            0              0  ...
# 20200714MIWID                          0            0              0  ...
# 20200704INLAM                          0            0              0  ...
# 20200701ILFRP                          1            0              0  ...
# ...                                  ...          ...            ...  ...
# 20220605INWEG                          0            1              0  ...
# 20220607MIPED                          0            1              0  ...
# 20220608ARLIL                          0            0              0  ...
# 20220609ALWAG                          0            0              0  ...
# 20220610ALBYB                          0            1              0  ...
#
#                situation_indiscriminate_shooting  situation_suicide_attempted  \
# Incident_ID
# 20200727AZCAO                                  0                            0
# 20200721SCBRO                                  0                            0
# 20200714MIWID                                  0                            0
# 20200704INLAM                                  0                            0
# 20200701ILFRP                                  0                            0
# ...                                          ...                          ...
# 20220605INWEG                                  0                            0
# 20220607MIPED                                  0                            0
# 20220608ARLIL                                  0                            0
# 20220609ALWAG                                  0                            0
# 20220610ALBYB                                  0                            0
#
#                situation_domestic_w__targeted_victim  situation_self_defense  \
# Incident_ID
# 20200727AZCAO                                      0                       0
# 20200721SCBRO                                      0                       0
# 20200714MIWID                                      0                       0
# 20200704INLAM                                      0                       0
# 20200701ILFRP                                      0                       0
# ...                                              ...                     ...
# 20220605INWEG                                      0                       0
# 20220607MIPED                                      0                       0
# 20220608ARLIL                                      0                       0
# 20220609ALWAG                                      0                       0
# 20220610ALBYB                                      0                       0
#
#                situation_bullying  situation_hostage_standoff  \
# Incident_ID
# 20200727AZCAO                   0                           0
# 20200721SCBRO                   0                           0
# 20200714MIWID                   0                           0
# 20200704INLAM                   0                           0
# 20200701ILFRP                   0                           0
# ...                           ...                         ...
# 20220605INWEG                   0                           0
# 20220607MIPED                   0                           0
# 20220608ARLIL                   0                           0
# 20220609ALWAG                   0                           0
# 20220610ALBYB                   0                           0
#
#                situation_anger_over_grade_suspension_discipline  \
# Incident_ID
# 20200727AZCAO                                                 0
# 20200721SCBRO                                                 0
# 20200714MIWID                                                 0
# 20200704INLAM                                                 0
# 20200701ILFRP                                                 0
# ...                                                         ...
# 20220605INWEG                                                 0
# 20220607MIPED                                                 0
# 20220608ARLIL                                                 0
# 20220609ALWAG                                                 0
# 20220610ALBYB                                                 0
#
#                situation_murder_suicide  situation_psychosis  \
# Incident_ID
# 20200727AZCAO                         0                    0
# 20200721SCBRO                         0                    0
# 20200714MIWID                         0                    0
# 20200704INLAM                         0                    0
# 20200701ILFRP                         0                    0
# ...                                 ...                  ...
# 20220605INWEG                         0                    0
# 20220607MIPED                         0                    0
# 20220608ARLIL                         0                    0
# 20220609ALWAG                         0                    0
# 20220610ALBYB                         0                    0
#
#                situation_officer_involved_shooting
# Incident_ID
# 20200727AZCAO                                    0
# 20200721SCBRO                                    0
# 20200714MIWID                                    0
# 20200704INLAM                                    0
# 20200701ILFRP                                    0
# ...                                            ...
# 20220605INWEG                                    0
# 20220607MIPED                                    0
# 20220608ARLIL                                    0
# 20220609ALWAG                                    1
# 20220610ALBYB                                    0
#
# [1034 rows x 34 columns]

# %%
DAY = timedelta(days=1)
WEEK = timedelta(weeks=1) 

x['next_week_events'] = None

for i, row in X.iterrows():
    incident_id = row['Incident_ID']
    d = row['Date']
    num_next_week_events = len(X[X['Date'] > d][X['Date'] <= d + WEEK])
    x.at[incident_id, 'next_week_events'] = num_next_week_events

x
# Out:
# /var/folders/wd/57_v9c5142x7mhyp18nb4bt80000gn/T/ipykernel_12843/3448359975.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   num_next_week_events = len(X[X['Date'] > d][X['Date'] <= d + WEEK])
#                high_coverage  num_victims  active_shooter_by_fbi  \
# Incident_ID
# 20200727AZCAO              0            0                      0
# 20200721SCBRO              0            1                      0
# 20200714MIWID              0            1                      0
# 20200704INLAM              0            1                      0
# 20200701ILFRP              0            1                      0
# ...                      ...          ...                    ...
# 20220605INWEG              0            2                      0
# 20220607MIPED              0            0                      0
# 20220608ARLIL              0            0                      0
# 20220609ALWAG              1            1                      0
# 20220610ALBYB              0            0                      0
#
#                gang_related  preplanned  bullied  domestic_violence  \
# Incident_ID
# 20200727AZCAO             0           0        0                  0
# 20200721SCBRO             0           0        0                  0
# 20200714MIWID             0           0        0                  0
# 20200704INLAM             0           0        0                  0
# 20200701ILFRP             1           0        0                  0
# ...                     ...         ...      ...                ...
# 20220605INWEG             0           0        0                  0
# 20220607MIPED             0           0        0                  0
# 20220608ARLIL             0           0        0                  0
# 20220609ALWAG             0           0        0                  0
# 20220610ALBYB             0           0        0                  0
#
#                incidents_with_accomplice  high_school  middle_school  ...  \
# Incident_ID                                                           ...
# 20200727AZCAO                          0            1              0  ...
# 20200721SCBRO                          0            0              0  ...
# 20200714MIWID                          0            0              0  ...
# 20200704INLAM                          0            0              0  ...
# 20200701ILFRP                          1            0              0  ...
# ...                                  ...          ...            ...  ...
# 20220605INWEG                          0            1              0  ...
# 20220607MIPED                          0            1              0  ...
# 20220608ARLIL                          0            0              0  ...
# 20220609ALWAG                          0            0              0  ...
# 20220610ALBYB                          0            1              0  ...
#
#                situation_suicide_attempted  \
# Incident_ID
# 20200727AZCAO                            0
# 20200721SCBRO                            0
# 20200714MIWID                            0
# 20200704INLAM                            0
# 20200701ILFRP                            0
# ...                                    ...
# 20220605INWEG                            0
# 20220607MIPED                            0
# 20220608ARLIL                            0
# 20220609ALWAG                            0
# 20220610ALBYB                            0
#
#                situation_domestic_w__targeted_victim  situation_self_defense  \
# Incident_ID
# 20200727AZCAO                                      0                       0
# 20200721SCBRO                                      0                       0
# 20200714MIWID                                      0                       0
# 20200704INLAM                                      0                       0
# 20200701ILFRP                                      0                       0
# ...                                              ...                     ...
# 20220605INWEG                                      0                       0
# 20220607MIPED                                      0                       0
# 20220608ARLIL                                      0                       0
# 20220609ALWAG                                      0                       0
# 20220610ALBYB                                      0                       0
#
#                situation_bullying  situation_hostage_standoff  \
# Incident_ID
# 20200727AZCAO                   0                           0
# 20200721SCBRO                   0                           0
# 20200714MIWID                   0                           0
# 20200704INLAM                   0                           0
# 20200701ILFRP                   0                           0
# ...                           ...                         ...
# 20220605INWEG                   0                           0
# 20220607MIPED                   0                           0
# 20220608ARLIL                   0                           0
# 20220609ALWAG                   0                           0
# 20220610ALBYB                   0                           0
#
#                situation_anger_over_grade_suspension_discipline  \
# Incident_ID
# 20200727AZCAO                                                 0
# 20200721SCBRO                                                 0
# 20200714MIWID                                                 0
# 20200704INLAM                                                 0
# 20200701ILFRP                                                 0
# ...                                                         ...
# 20220605INWEG                                                 0
# 20220607MIPED                                                 0
# 20220608ARLIL                                                 0
# 20220609ALWAG                                                 0
# 20220610ALBYB                                                 0
#
#                situation_murder_suicide  situation_psychosis  \
# Incident_ID
# 20200727AZCAO                         0                    0
# 20200721SCBRO                         0                    0
# 20200714MIWID                         0                    0
# 20200704INLAM                         0                    0
# 20200701ILFRP                         0                    0
# ...                                 ...                  ...
# 20220605INWEG                         0                    0
# 20220607MIPED                         0                    0
# 20220608ARLIL                         0                    0
# 20220609ALWAG                         0                    0
# 20220610ALBYB                         0                    0
#
#                situation_officer_involved_shooting  next_week_events
# Incident_ID
# 20200727AZCAO                                    0                 1
# 20200721SCBRO                                    0                 1
# 20200714MIWID                                    0                 1
# 20200704INLAM                                    0                 0
# 20200701ILFRP                                    0                 1
# ...                                            ...               ...
# 20220605INWEG                                    0                 4
# 20220607MIPED                                    0                 3
# 20220608ARLIL                                    0                 2
# 20220609ALWAG                                    1                 1
# 20220610ALBYB                                    0                 0
#
# [1034 rows x 35 columns]

# %%
def get_ci(v):
    mid = np.mean(v)
    se = np.std(v) / np.sqrt(len(v))
    return (mid - 1.96*se, mid + 1.96*se)

# %% [markdown]
# ### Unadjusted ATE estimation

# %%
y1_est = x[x['high_coverage']==1]['next_week_events'].mean()
y0_est = x[x['high_coverage']==0]['next_week_events'].mean()

unadjusted_ate = y1_est - y0_est

print('unadjusted ATE:', y1_est - y0_est)
# Out:
# unadjusted ATE: 0.014104501534093483

# %%
# Using bootstrap

unadjusted_ates = []

B = 100
sample_size = 500

for i in range(B):
    sample = x.sample(sample_size)
    y1_est = sample[sample['high_coverage']==1]['next_week_events'].mean()
    y0_est = sample[sample['high_coverage']==0]['next_week_events'].mean()
    unadjusted_ates.append(y1_est - y0_est)


get_ci(unadjusted_ates)
# Out:
# (-0.07373892950412529, 0.04431621992016849)

# %% [markdown]
# ### S-Learner

# %%
from sklearn.linear_model import LinearRegression

target_label = 'next_week_events'
features = list(x.columns)
features.remove(target_label)

X_train, y_train = x[features], x[target_label]

reg = LinearRegression()
reg.fit(X_train, y_train)
y_predict = reg.predict(X_train)

L1_error = ((y_train - y_predict).abs()).mean()
print("L1_error:", L1_error)

x_do_1, x_do_0 = X_train.copy(), X_train.copy()
x_do_1['high_coverage'] = 1
x_do_0['high_coverage'] = 0

y_predict_do_1 = reg.predict(x_do_1)
y_predict_do_0 = reg.predict(x_do_0)

s_learner_lin_reg_ate = (y_predict_do_1 - y_predict_do_0).mean()

print('ATE estimation:', (y_predict_do_1 - y_predict_do_0).mean())
# Out:
# L1_error: 2.835178778665989
# ATE estimation: 0.6715563923826144

# %%
# S-learner/Linear regression ATE estimation using bootstrap

s_learner_lin_reg_ates = []
for i in range(100):
    sample = x.sample(500)
    X_train, y_train = sample[features], sample[target_label]

    reg = LinearRegression()
    reg.fit(X_train, y_train)
    y_predict = reg.predict(X_train)

    x_do_1, x_do_0 = X_train.copy(), X_train.copy()
    x_do_1['high_coverage'] = 1
    x_do_0['high_coverage'] = 0

    y_predict_do_1 = reg.predict(x_do_1)
    y_predict_do_0 = reg.predict(x_do_0)

    s_learner_lin_reg_ates.append((y_predict_do_1 - y_predict_do_0).mean())

ci = get_ci(s_learner_lin_reg_ates)
np.mean(ci), ci
# Out:
# (0.669162235458832, (0.6057581395201671, 0.7325663313974969))

# %%
from sklearn.tree import DecisionTreeRegressor

X_train, y_train = x[features], x[target_label]

reg = DecisionTreeRegressor()
reg.fit(X_train, y_train)
y_predict = reg.predict(X_train)

x_do_1, x_do_0 = X_train.copy(), X_train.copy()
x_do_1['high_coverage'] = 1
x_do_0['high_coverage'] = 0

y_predict_do_1 = reg.predict(x_do_1)
y_predict_do_0 = reg.predict(x_do_0)

s_learner_dec_tree_ate = (y_predict_do_1 - y_predict_do_0).mean()

print("ATE:", (y_predict_do_1 - y_predict_do_0).mean())
# Out:
# ATE: 0.2266224909841931

# %%
# S-learner / Decision tree ATE Estimation using bootstrap

s_learner_dec_tree_ates = []

for i in range(100):
    sample = x.sample(500)
    X_train, y_train = sample[features], sample[target_label]

    reg = DecisionTreeRegressor()
    reg.fit(X_train, y_train)
    y_predict = reg.predict(X_train)

    x_do_1, x_do_0 = X_train.copy(), X_train.copy()
    x_do_1['high_coverage'] = 1
    x_do_0['high_coverage'] = 0

    y_predict_do_1 = reg.predict(x_do_1)
    y_predict_do_0 = reg.predict(x_do_0)

    s_learner_dec_tree_ates.append((y_predict_do_1 - y_predict_do_0).mean())

ci = get_ci(s_learner_dec_tree_ates)
np.mean(ci), ci
# Out:
# (0.3915685396825397, (0.30718146373770244, 0.4759556156273769))

# %% [markdown]
# ### T-Learner

# %% [markdown]
# Using linear regression

# %%
t_learner_features = features.copy()
t_learner_features.remove('high_coverage')

# y=f(X) for high coverage events
x_high = x[x.high_coverage == 1]
x_high_train, y_high_train = x_high[t_learner_features], x_high[target_label]

reg_high = LinearRegression()
reg_high.fit(x_high_train, y_high_train)

# y=f(X) for low coverage events
x_low = x[x.high_coverage == 0]
x_low_train, y_low_train = x_low[t_learner_features], x_low[target_label]

reg_low = LinearRegression()
reg_low.fit(x_low_train, y_low_train)

# estimate using f1
y1 = reg_high.predict(x[t_learner_features])

# estimate using f0
y0 = reg_low.predict(x[t_learner_features])

t_learner_lin_reg_ate = (y1 - y0).mean()

print('ATE estimation:', (y1 - y0).mean())
# Out:
# ATE estimation: 0.6098807640493377

# %%
# T-learner, linear regression, ATE estimation using bootstrap

t_learner_lin_reg_ates = []

for i in range(100):
    sample = x.sample(500)
        
    # y=f(X) for high coverage events
    x_high = sample[sample.high_coverage == 1]
    x_high_train, y_high_train = x_high[t_learner_features], x_high[target_label]

    reg_high = LinearRegression()
    reg_high.fit(x_high_train, y_high_train)

    # y=f(X) for low coverage events
    x_low = sample[sample.high_coverage == 0]
    x_low_train, y_low_train = x_low[t_learner_features], x_low[target_label]

    reg_low = LinearRegression()
    reg_low.fit(x_low_train, y_low_train)

    # estimate using f1
    y1 = reg_high.predict(sample[t_learner_features])

    # estimate using f0
    y0 = reg_low.predict(sample[t_learner_features])

    t_learner_lin_reg_ates.append((y1 - y0).mean())

ci = get_ci(t_learner_lin_reg_ates)
np.mean(ci), ci
# Out:
# (0.6767008596462848, (0.5761360536877539, 0.7772656656048157))

# %% [markdown]
# Using desicion trees

# %%
reg_high = DecisionTreeRegressor()
reg_high.fit(x_high_train, y_high_train)

reg_low = DecisionTreeRegressor()
reg_low.fit(x_low_train, y_low_train)

# estimate using f1
y1 = reg_high.predict(x[t_learner_features])

# estimate using f0
y0 = reg_low.predict(x[t_learner_features])

t_learner_dec_tree_ate = (y1 - y0).mean()

print('ATE estimation:', (y1 - y0).mean())
# Out:
# ATE estimation: 0.13684719535783363

# %%
# T-learner, decision trees, ATE estimation using bootstrap

t_learner_dec_tree_ates = []

for i in range(100):
    # y=f(X) for high coverage events
    x_high = sample[sample.high_coverage == 1]
    x_high_train, y_high_train = x_high[t_learner_features], x_high[target_label]

    # y=f(X) for low coverage events
    x_low = sample[sample.high_coverage == 0]
    x_low_train, y_low_train = x_low[t_learner_features], x_low[target_label]
    
    sample = x.sample(500)
    reg_high = DecisionTreeRegressor()
    reg_high.fit(x_high_train, y_high_train)

    reg_low = DecisionTreeRegressor()
    reg_low.fit(x_low_train, y_low_train)

    # estimate using f1
    y1 = reg_high.predict(sample[t_learner_features])

    # estimate using f0
    y0 = reg_low.predict(sample[t_learner_features])

    t_learner_dec_tree_ates.append((y1 - y0).mean())

ci = get_ci(t_learner_dec_tree_ates)
np.mean(ci), ci
# Out:
# (0.3633885678210678, (0.2470708012672061, 0.47970633437492954))

# %% [markdown]
# ### IPW & Propensity estimation
#
# $ e(x) = P(T=1 | x) $

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

p_target_label = "high_coverage"
p_features = features.copy()
p_features.remove(p_target_label)

p_reg = LogisticRegression()
p_reg.fit(x[p_features], x[p_target_label])
high_coverage_predict = p_reg.predict(x[p_features])

print("Propensity score training accuracy:", metrics.accuracy_score(x[p_target_label], high_coverage_predict))
print("Propensity score training recall:", metrics.recall_score(x[p_target_label], high_coverage_predict))
print("Propensity score training precision:", metrics.precision_score(x[p_target_label], high_coverage_predict))
# Out:
# Propensity score training accuracy: 0.8036750483558994
# Propensity score training recall: 0.3545816733067729
# Propensity score training precision: 0.6846153846153846

# %% [markdown]
# Adjustment:
#
# $ \hat{ATE} = {{1} \over {n}} \Sigma {  {{t_i \cdot y_i} \over {e(x_i)}} - {{(1-t_i) \cdot y_i} \over {1-e(x_i)}}  }  $

# %%
# propensity
p = p_reg.predict_proba(x[p_features])[:,1]

# treatment
t = x["high_coverage"]

# outcome
y = x["next_week_events"]

ate_ipw_est = np.mean(t * y / p - (1-t) * y / (1-p))
print("Estimated ATE using IPW:", ate_ipw_est)
# Out:
# Estimated ATE using IPW: -0.3177603306887336

# %%
# Estimating ATE using IPW and bootstrap
ipw_ates = []

for i in range(100):
    sample = x.sample(500)
    p = p_reg.predict_proba(sample[p_features])[:,1]
    t = sample["high_coverage"]
    y = sample["next_week_events"]
    ipw_ates.append(np.mean(t * y / p - (1-t) * y / (1-p)))

ci = get_ci(ipw_ates)
np.mean(ci), ci
# Out:
# (-0.31140493907590544, (-0.4204582456822716, -0.2023516324695393))

# %%
plt.figure(figsize=(5,8))
plt.title("ATE estimate using high/low media coverage treatment")

# bootstrap
# unadjusted_ates
# s_learner_lin_reg_ates
# s_learner_dec_tree_ates
# t_learner_lin_reg_ates
# t_learner_dec_tree_ates
# ipw_ates

ci = get_ci(unadjusted_ates)
plt.scatter([unadjusted_ate], [5], marker=7, s=200)
plt.scatter(ci, [5,5], marker="|", c='black', s=200)
plt.plot(ci, [5,5], c='black')

ci = get_ci(s_learner_lin_reg_ates)
plt.scatter([s_learner_lin_reg_ate], [4], marker=7, s=200)
plt.scatter(ci, [4,4], marker="|", c='black', s=200)
plt.plot(ci, [4,4], c='black')

ci = get_ci(s_learner_dec_tree_ates)
plt.scatter([s_learner_dec_tree_ate], [3], marker=7, s=200)
plt.scatter(ci, [3,3], marker="|", c='black', s=200)
plt.plot(ci, [3,3], c='black')

ci = get_ci(t_learner_lin_reg_ates)
plt.scatter([t_learner_lin_reg_ate], [2], marker=7, s=200)
plt.scatter(ci, [2,2], marker="|", c='black', s=200)
plt.plot(ci, [2,2], c='black')

ci = get_ci(t_learner_dec_tree_ates)
plt.scatter([t_learner_dec_tree_ate], [1], marker=7, s=200)
plt.scatter(ci, [1,1], marker="|", c='black', s=200)
plt.plot(ci, [1,1], c='black')

ci = get_ci(ipw_ates)
plt.scatter([ate_ipw_est], [0], marker=7, s=200)
plt.scatter(ci, [0,0], marker="|", c='black', s=200)
plt.plot(ci, [0,0], c='black')

plt.xlabel("Average treatment effect")

plt.yticks(range(5+1), ['IPW', 'T-Learner (Decision Tree)', 'T-Learner (Linear Reg.)', 'S-Learner (Decision Tree)', 'S-Learner (Linear Reg.)', 'Unadjusted'])
plt.ylim((-1, 6))
plt.grid(True, "both")

plt.show()

# %%
x.columns
# Out:
# Index(['high_coverage', 'num_victims', 'active_shooter_by_fbi', 'gang_related',
#        'preplanned', 'bullied', 'domestic_violence',
#        'incidents_with_accomplice', 'high_school', 'middle_school',
#        'elementry_school', 'in_school', 'out_school', 'school_bus',
#        'during_school', 'is_summer_time', 'targeted', 'random_shooting',
#        'situation_accidental', 'situation_escalation_of_dispute',
#        'situation_illegal_activity', 'situation_drive_by_shooting',
#        'situation_intentional_property_damage', 'situation_unknown',
#        'situation_indiscriminate_shooting', 'situation_suicide_attempted',
#        'situation_domestic_w__targeted_victim', 'situation_self_defense',
#        'situation_bullying', 'situation_hostage_standoff',
#        'situation_anger_over_grade_suspension_discipline',
#        'situation_murder_suicide', 'situation_psychosis',
#        'situation_officer_involved_shooting', 'next_week_events'],
#       dtype='object')
